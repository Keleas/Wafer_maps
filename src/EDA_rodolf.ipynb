# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import os

# %matplotlib inline

# %%
root_path = '../input/rudolf_data/'
name_1 = 'good_defect_2734900.csv'
name_2 = 'bad_defect_148199.csv'
name_3 = 'good_layer_2197.csv'
name_4 = 'bad_layer_120.csv'

df = pd.read_csv(os.path.join(root_path, name_3))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2197 entries, 0 to 2196
# Data columns (total 10 columns):
# LAYER_SCAN_INDEX    2197 non-null int64
# LOT_ID              2197 non-null object
# WAFER_ID            2197 non-null object
# SCAN_DATE_TIME      2196 non-null object
# DEFECT_COUNT        2197 non-null int64
# X_ORIGIN_DIE        2197 non-null float64
# Y_ORIGIN_DIE        2197 non-null float64
# X_DIE_SIZE          2197 non-null float64
# Y_DIE_SIZE          2197 non-null float64
# WAFER_SIZE          2197 non-null int64
# dtypes: float64(4), int64(3), object(3)
# memory usage: 171.8+ KB

# %%
df.head(20)
# Out:
#     LAYER_SCAN_INDEX                   LOT_ID             WAFER_ID  \
# 0           30024588  Z11N_CORNER_DEFECT_REV3              1760682
# 1           30024587             BN41R15-Test                   11
# 2           30024585                   WAH200          WAH20W07-G4
# 3           30024584                   WAH200          WAH20W06-E1
# 4           30024583                   WAH200          WAH20W05-B6
# 5           30024572                 F12609.1             F1260901
# 6           30024570                 BH4098_1          BH4098-20B0
# 7           30024569    15umBH20umBD-Sampling  Repeeaattbbitltty_7
# 8           30024568                  BN36R07                   11
# 9           30024560                    7N0J2                7N0J2
# 10          30024559                    5X6NQ                5X6NQ
# 11          30024557         eDR-PC-Lot6-45nm             S6-post8
# 12          30024528                 ZA927289          ZA927289.10
# ...

# %%
(np.unique(df.WAFER_SIZE))
# Out:
# array([100, 125, 150, 185, 200, 300, 330, 515], dtype=int64)

# %%
np.max(df.X_DIE_COORDINATE), np.min(df.X_DIE_COORDINATE)
# Out:
# (755, -228)

# %%
np.max(df.Y_DIE_COORDINATE), np.min(df.Y_DIE_COORDINATE)
# Out:
# (751, -358)

# %%
np.max(df.Y_COORDINATE), np.min(df.Y_COORDINATE)
# Out:
# (243189.203125, -242453.921875)

# %%
np.max(df.X_COORDINATE), np.min(df.X_COORDINATE)
# Out:
# (240853.140625, -241010.71875)
