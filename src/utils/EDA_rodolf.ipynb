# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import os

# %matplotlib inline

# %%
root_path = '../input/rudolf_data/'
name_1 = 'good_defect_2734900.csv'
name_2 = 'bad_defect_148199.csv'
name_3 = 'good_layer_2197.csv'
name_4 = 'bad_layer_120.csv'

df = pd.read_csv(os.path.join(root_path, name_1))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2734900 entries, 0 to 2734899
# Data columns (total 10 columns):
# LAYER_SCAN_INDEX    int64
# DEFECT_INDEX        float64
# DEFECT_SITE_ID      float64
# X_DIE_COORDINATE    int64
# Y_DIE_COORDINATE    int64
# X_COORDINATE        float64
# Y_COORDINATE        float64
# X_DEFECT_SIZE       float64
# Y_DEFECT_SIZE       float64
# D_SIZE              float64
# dtypes: float64(7), int64(3)
# memory usage: 208.7 MB

# %%
df.head(20)
# Out:
#     LAYER_SCAN_INDEX  DEFECT_INDEX  DEFECT_SITE_ID  X_DIE_COORDINATE  \
# 0           30024588  2.191609e+09           212.0                27
# 1           30024588  2.191609e+09           213.0                27
# 2           30024588  2.191609e+09           214.0                27
# 3           30024588  2.191609e+09           215.0                27
# 4           30024588  2.191609e+09           216.0                27
# 5           30024588  2.191609e+09           218.0                28
# 6           30024588  2.191609e+09           221.0                28
# 7           30024588  2.191609e+09           222.0                28
# 8           30024588  2.191609e+09           223.0                28
# 9           30024588  2.191609e+09           224.0                28
# 10          30024588  2.191609e+09           225.0                28
# 11          30024588  2.191609e+09           226.0                28
# 12          30024588  2.191609e+09           227.0                28
# 13          30024588  2.191609e+09           230.0                28
# 14          30024588  2.191609e+09           231.0                28
# 15          30024588  2.191609e+09           232.0                28
# 16          30024588  2.191609e+09           233.0                28
# 17          30024588  2.191609e+09           236.0                29
# 18          30024588  2.191609e+09           237.0                29
# 19          30024588  2.191609e+09           238.0                29
#
#     Y_DIE_COORDINATE  X_COORDINATE   Y_COORDINATE  X_DEFECT_SIZE  \
# 0                 13   7924.711426  -10131.330078       7.540703
# 1                 12   6738.398438  -10310.992188      35.818100
# 2                 12   7911.910156  -10235.625977      33.932686
# 3                 12   7920.530273  -20160.968750      16.023636
# 4                 10   7846.971680  -30282.171875      15.081406
# 5                 11   9187.786133  -20255.125000      49.014091
# 6                 12   8032.506836  -20161.429688      26.392937
# 7                 12   8709.749023  -20163.386719      21.678925
# 8                 12   8973.670898  -20163.414062      46.186447
# 9                 12   9181.038086  -20163.437500      31.105042
# 10                14   9340.494141    -108.356949      19.793510
# 11                11   9498.481445  -20255.660156      45.243263
# 12                 1  11728.515625 -130462.414062      43.357849
# 13                10  13336.306641  -30313.234375      23.564339
# 14                 9  13134.826172  -43594.449219      88.602066
# 15                 0  12400.391602 -130904.585938      42.416573
# 16                 0  12114.349609 -130935.500000      41.473389
# 17                13  13803.106445    -199.306488      48.071861
# 18                13  13442.646484   -6965.554199       3.769875
# 19                14  13491.335938    -108.271599      37.702560
#
#     Y_DEFECT_SIZE      D_SIZE
# 0       15.081406   15.087126
# 1       29.219627   38.424442
# 2       21.679878   37.914326
# 3       10.368347   17.040081
# 4        4.713058   15.447836
# 5        5.655289   49.014034
# 6        8.483887   26.392174
# 7        4.713058   21.679285
# 8        4.713058   46.186302
# 9        4.713058   31.105061
# 10       4.712887   19.794128
# 11       4.713058   45.243725
# 12       4.714966   43.358570
# 13      66.923141   70.196854
# 14     247.898102  247.897903
# 15      27.328491   47.916027
# 16      11.322021   41.473415
# 17       5.655468   48.071461
# 18      19.793987   19.794128
# 19       4.712894   37.703106

# %%
(np.unique(df.WAFER_SIZE))
# Out:
# array([100, 125, 150, 185, 200, 300, 330, 515], dtype=int64)

# %%
np.max(df.X_DIE_COORDINATE), np.min(df.X_DIE_COORDINATE)
# Out:
# (755, -228)

# %%
np.max(df.Y_DIE_COORDINATE), np.min(df.Y_DIE_COORDINATE)
# Out:
# (751, -358)

# %%
np.max(df.Y_COORDINATE), np.min(df.Y_COORDINATE)
# Out:
# (243189.203125, -242453.921875)

# %%
np.max(df.X_COORDINATE), np.min(df.X_COORDINATE)
# Out:
# (240853.140625, -241010.71875)
